# %% [markdown]
# # Model-Based RL
# In this exercise you will implement a policy and model network which work in tandem to solve the CartPole reinforcement learning problem.

# %% [markdown]
# What is a model and why would we want to use one? In this case, a model is going to be a neural network that attempts to learn the dynamics of the real environment. For example, in the CartPole we would like a model to be able to predict the next position of the Cart given the previous position and an action. By learning an accurate model, we can train our agent using the model rather than requiring to use the real environment every time. While this may seem less useful when the real environment is itself a simulation, like in our CartPole task, it can have huge advantages when attempting to learn policies for acting in the physical world.

# %% [markdown]
# How are we going to accomplish this in Tensorflow? We are going to be using a neural network that will learn the transition dynamics between a previous observation and action, and the expected new observation, reward, and done state. Our training procedure will involve switching between training our model using the real environment, and training our agent’s policy using the model environment. By using this approach we will be able to learn a policy that allows our agent to solve the CartPole task without actually ever training the policy on the real environment!

# %% [markdown]
# ### Loading libraries and starting CartPole environment

# %%
from __future__ import print_function
import numpy as np
try:
    import cPickle as pickle
except:
    import pickle
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import math

# %%
import sys
if sys.version_info.major > 2:
    xrange = range
del sys

# %%
import gym
env = gym.make('CartPole-v0')

# %% [markdown]
# ### Setting Hyper-parameters

# %%
# hyperparameters
H = 8 # number of hidden layer neurons
learning_rate = 1e-2
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2
resume = False # resume from previous checkpoint?

model_bs = 3 # Batch size when learning from model
real_bs = 3 # Batch size when learning from real environment

# model initialization
D = 4 # input dimensionality

# %% [markdown]
# ### Policy Network

# %%
tf.reset_default_graph()
observations = tf.placeholder(tf.float32, [None,4] , name="input_x")
W1 = tf.get_variable("W1", shape=[4, H],
           initializer=tf.contrib.layers.xavier_initializer())
layer1 = tf.nn.relu(tf.matmul(observations,W1))
W2 = tf.get_variable("W2", shape=[H, 1],
           initializer=tf.contrib.layers.xavier_initializer())
score = tf.matmul(layer1,W2)
probability = tf.nn.sigmoid(score)

tvars = tf.trainable_variables()
input_y = tf.placeholder(tf.float32,[None,1], name="input_y")
advantages = tf.placeholder(tf.float32,name="reward_signal")
adam = tf.train.AdamOptimizer(learning_rate=learning_rate)
W1Grad = tf.placeholder(tf.float32,name="batch_grad1")
W2Grad = tf.placeholder(tf.float32,name="batch_grad2")
batchGrad = [W1Grad,W2Grad]

################################################################################
# TODO: Implement the loss function.                                           #
# This sends the weights in the direction of making actions that gave good     #
# advantage (reward overtime) more likely, and actions that didn't less likely.#
################################################################################
loss = -tf.reduce_mean(tf.log(input_y*(input_y-probability)+(1-input_y)*(input_y+probability))*advantages) 
################################################################################
#                                 END OF YOUR CODE                             #
################################################################################

newGrads = tf.gradients(loss,tvars)
updateGrads = adam.apply_gradients(zip(batchGrad,tvars))

# %% [markdown]
# ### Model Network
# Here we implement a multi-layer neural network that predicts the next observation, reward, and done state from a current state and action.

# %%
mH = 256 # model layer size

input_data = tf.placeholder(tf.float32, [None, 5])
with tf.variable_scope('rnnlm'):
    softmax_w = tf.get_variable("softmax_w", [mH, 50])
    softmax_b = tf.get_variable("softmax_b", [50])

previous_state = tf.placeholder(tf.float32, [None,5] , name="previous_state")
W1M = tf.get_variable("W1M", shape=[5, mH],
           initializer=tf.contrib.layers.xavier_initializer())
B1M = tf.Variable(tf.zeros([mH]),name="B1M")
layer1M = tf.nn.relu(tf.matmul(previous_state,W1M) + B1M)
W2M = tf.get_variable("W2M", shape=[mH, mH],
           initializer=tf.contrib.layers.xavier_initializer())
B2M = tf.Variable(tf.zeros([mH]),name="B2M")
layer2M = tf.nn.relu(tf.matmul(layer1M,W2M) + B2M)
wO = tf.get_variable("wO", shape=[mH, 4],
           initializer=tf.contrib.layers.xavier_initializer())
wR = tf.get_variable("wR", shape=[mH, 1],
           initializer=tf.contrib.layers.xavier_initializer())
wD = tf.get_variable("wD", shape=[mH, 1],
           initializer=tf.contrib.layers.xavier_initializer())

bO = tf.Variable(tf.zeros([4]),name="bO")
bR = tf.Variable(tf.zeros([1]),name="bR")
bD = tf.Variable(tf.ones([1]),name="bD")


predicted_observation = tf.matmul(layer2M,wO,name="predicted_observation") + bO
predicted_reward = tf.matmul(layer2M,wR,name="predicted_reward") + bR
predicted_done = tf.sigmoid(tf.matmul(layer2M,wD,name="predicted_done") + bD)

true_observation = tf.placeholder(tf.float32,[None,4],name="true_observation")
true_reward = tf.placeholder(tf.float32,[None,1],name="true_reward")
true_done = tf.placeholder(tf.float32,[None,1],name="true_done")


predicted_state = tf.concat([predicted_observation,predicted_reward,predicted_done],1)

observation_loss = tf.square(true_observation - predicted_observation)

reward_loss = tf.square(true_reward - predicted_reward)

done_loss = tf.multiply(predicted_done, true_done) + tf.multiply(1-predicted_done, 1-true_done)
done_loss = -tf.log(done_loss)

model_loss = tf.reduce_mean(observation_loss + done_loss + reward_loss)

modelAdam = tf.train.AdamOptimizer(learning_rate=learning_rate)
updateModel = modelAdam.minimize(model_loss)

# %% [markdown]
# ### Helper-functions

# %%
def resetGradBuffer(gradBuffer):
    for ix,grad in enumerate(gradBuffer):
        gradBuffer[ix] = grad * 0
    return gradBuffer

def discount_rewards(r):
    ################################################################################
    # TODO: Implement the discounted rewards function                              #
    # Return discounted rewards weighed by gamma. Each reward will be replaced     #
    # with a weight reward that involves itself and all the other rewards occuring #
    # after it. The later the reward after it happens, the less effect it has on   #
    # the current rewards's discounted reward                                      #
    # Hint: [r0, r1, r2, ..., r_N] will look someting like:                        #
    #       [(r0 + r1*gamma^1 + ... r_N*gamma^N), (r1 + r2*gamma^1 + ...), ...]    #
    ################################################################################
    dcr = []
    dcr.append(np.power(gamma, range(len(r))).dot(r))
    for i, ri in enumerate(r[:len(r)-1]):
        dcr.append((dcr[i] - ri) / gamma)
    return np.array(dcr)        
    ################################################################################
    #                                 END OF YOUR CODE                             #
    ################################################################################

# This function uses our model to produce a new state when given a previous state and action
def stepModel(sess, xs, action):
    toFeed = np.reshape(np.hstack([xs[-1][0],np.array(action)]),[1,5])
    myPredict = sess.run([predicted_state],feed_dict={previous_state: toFeed})
    reward = myPredict[0][:,4]
    observation = myPredict[0][:,0:4]
    observation[:,0] = np.clip(observation[:,0],-2.4,2.4)
    observation[:,2] = np.clip(observation[:,2],-0.4,0.4)
    doneP = np.clip(myPredict[0][:,5],0,1)
    if doneP > 0.1 or len(xs)>= 300:
        done = True
    else:
        done = False
    return observation, reward, done

# %% [markdown]
# ## Training the Policy and Model

# %%
xs,drs,ys,ds = [],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 1
real_episodes = 1
init = tf.global_variables_initializer()
batch_size = real_bs

drawFromModel = False # When set to True, will use model for observations
trainTheModel = True # Whether to train the model
trainThePolicy = False # Whether to train the policy
switch_point = 1

# Launch the graph
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.4
with tf.Session(config=config) as sess:
    rendering = False
    sess.run(init)
    observation = env.reset()
    x = observation
    gradBuffer = sess.run(tvars)
    gradBuffer = resetGradBuffer(gradBuffer)
    
    while episode_number <= 5000:
        # Start displaying environment once performance is acceptably high.
        if (reward_sum/batch_size > 150 and drawFromModel == False) or rendering == True : 
            #env.render()
            rendering = True
            
        x = np.reshape(observation,[1,4])

        tfprob = sess.run(probability,feed_dict={observations: x})
        action = 1 if np.random.uniform() < tfprob else 0

        # record various intermediates (needed later for backprop)
        xs.append(x) 
        y = 1 if action == 0 else 0 
        ys.append(y)
        
        # step the  model or real environment and get new measurements
        if drawFromModel == False:
            observation, reward, done, info = env.step(action)
        else:
            observation, reward, done = stepModel(sess,xs,action)
                
        reward_sum += reward
        
        ds.append(done*1)
        drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

        if done: 
            
            if drawFromModel == False: 
                real_episodes += 1
            episode_number += 1

            # stack together all inputs, hidden states, action gradients, and rewards for this episode
            epx = np.vstack(xs)
            epy = np.vstack(ys)
            epr = np.vstack(drs)
            epd = np.vstack(ds)
            xs,drs,ys,ds = [],[],[],[] # reset array memory
            
            if trainTheModel == True:
                
                ################################################################################
                # TODO: Run the model network and compute predicted_state                      #
                # Output: 'pState'                                                             #
                ################################################################################
                _previous_state = np.concatenate([epx[:-1], np.absolute(epy-1)[:-1]], axis=1)
                pState, _ = sess.run([predicted_state, updateModel], 
                                     feed_dict={previous_state: _previous_state,
                                                true_observation: epx[1:],
                                                true_reward: epr[1:],
                                                true_done: epd[1:]})
                ################################################################################
                #                                 END OF YOUR CODE                             #
                ################################################################################
                

            if trainThePolicy == True:
                
                ################################################################################
                # TODO: Run the policy network and compute newGrads                            #
                # Output: 'tGrad'                                                              #
                ################################################################################
                discounted_epr = discount_rewards(epr)
                discounted_epr = (discount_rewards(epr) - np.mean(discounted_epr)) / np.std(discounted_epr)
                tGrad = sess.run(newGrads, feed_dict={observations:epx, advantages:discounted_epr, input_y:epy})
                ################################################################################
                #                                 END OF YOUR CODE                             #
                ################################################################################
                
                # If gradients becom too large, end training process
                if np.sum(tGrad[0] == tGrad[0]) == 0:
                    break
                for ix,grad in enumerate(tGrad):
                    gradBuffer[ix] += grad
                
            if switch_point + batch_size == episode_number: 
                switch_point = episode_number
                if trainThePolicy == True:
                    
                    ################################################################################
                    # TODO:                                                                        #
                    # (1) Run the policy network and update gradients                              #
                    # (2) Reset gradBuffer to 0                                                    #
                    ################################################################################
                    sess.run(updateGrads, feed_dict={W1Grad: gradBuffer[0], W2Grad:gradBuffer[1]})
                    resetGradBuffer(gradBuffer)                     
                    ################################################################################
                    #                                 END OF YOUR CODE                             #
                    ################################################################################

                running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
                if drawFromModel == False:
                    print('World Perf: Episode %f. Reward %f. action: %f. mean reward %f.' % (real_episodes,reward_sum/real_bs,action, running_reward/real_bs))
                    if reward_sum/batch_size > 200:
                        break
                reward_sum = 0

                # Once the model has been trained on 100 episodes
                if episode_number > 100:
                    
                    ################################################################################
                    # TODO: Alternating between training the policy from the model and training    #
                    # the model from the real environment.                                         #
                    ################################################################################
                    trainTheModel = not trainTheModel
                    trainThePolicy = not trainThePolicy
                    drawFromModel = not drawFromModel
                    ################################################################################
                    #                                 END OF YOUR CODE                             #
                    ################################################################################
            
            if drawFromModel == True:
                observation = np.random.uniform(-0.1,0.1,[4]) # Generate reasonable starting point
                batch_size = model_bs
            else:
                observation = env.reset()
                batch_size = real_bs
                
print(real_episodes)
# Out:
# World Perf: Episode 4.000000. Reward 19.666667. action: 1.000000. mean reward 19.666667.
# World Perf: Episode 7.000000. Reward 21.000000. action: 0.000000. mean reward 19.680000.
# World Perf: Episode 10.000000. Reward 17.333333. action: 0.000000. mean reward 19.656533.
# World Perf: Episode 13.000000. Reward 18.666667. action: 1.000000. mean reward 19.646635.
# World Perf: Episode 16.000000. Reward 24.000000. action: 0.000000. mean reward 19.690168.
# World Perf: Episode 19.000000. Reward 17.333333. action: 0.000000. mean reward 19.666600.
# World Perf: Episode 22.000000. Reward 17.666667. action: 0.000000. mean reward 19.646601.
# World Perf: Episode 25.000000. Reward 17.333333. action: 0.000000. mean reward 19.623468.
# World Perf: Episode 28.000000. Reward 11.666667. action: 1.000000. mean reward 19.543900.
# World Perf: Episode 31.000000. Reward 13.333333. action: 0.000000. mean reward 19.481794.
# World Perf: Episode 34.000000. Reward 19.000000. action: 1.000000. mean reward 19.476976.
# World Perf: Episode 37.000000. Reward 22.000000. action: 1.000000. mean reward 19.502207.
# World Perf: Episode 40.000000. Reward 19.666667. action: 0.000000. mean reward 19.503851.
# World Perf: Episode 43.000000. Reward 14.000000. action: 0.000000. mean reward 19.448813.
# World Perf: Episode 46.000000. Reward 21.333333. action: 1.000000. mean reward 19.467658.
# World Perf: Episode 49.000000. Reward 14.333333. action: 0.000000. mean reward 19.416315.
# World Perf: Episode 52.000000. Reward 35.666667. action: 1.000000. mean reward 19.578818.
# World Perf: Episode 55.000000. Reward 21.666667. action: 0.000000. mean reward 19.599697.
# World Perf: Episode 58.000000. Reward 21.333333. action: 0.000000. mean reward 19.617033.
# World Perf: Episode 61.000000. Reward 35.333333. action: 0.000000. mean reward 19.774196.
# World Perf: Episode 64.000000. Reward 22.666667. action: 0.000000. mean reward 19.803121.
# World Perf: Episode 67.000000. Reward 15.333333. action: 0.000000. mean reward 19.758423.
# World Perf: Episode 70.000000. Reward 14.000000. action: 1.000000. mean reward 19.700839.
# World Perf: Episode 73.000000. Reward 21.000000. action: 1.000000. mean reward 19.713830.
# World Perf: Episode 76.000000. Reward 12.333333. action: 1.000000. mean reward 19.640025.
# World Perf: Episode 79.000000. Reward 29.000000. action: 1.000000. mean reward 19.733625.
# World Perf: Episode 82.000000. Reward 23.333333. action: 1.000000. mean reward 19.769622.
# World Perf: Episode 85.000000. Reward 12.666667. action: 1.000000. mean reward 19.698593.
# World Perf: Episode 88.000000. Reward 22.000000. action: 1.000000. mean reward 19.721607.
# World Perf: Episode 91.000000. Reward 30.333333. action: 0.000000. mean reward 19.827724.
# World Perf: Episode 94.000000. Reward 21.666667. action: 0.000000. mean reward 19.846113.
# World Perf: Episode 97.000000. Reward 14.666667. action: 1.000000. mean reward 19.794319.
# World Perf: Episode 100.000000. Reward 15.000000. action: 1.000000. mean reward 19.746376.
# World Perf: Episode 103.000000. Reward 14.666667. action: 0.000000. mean reward 19.695579.
# World Perf: Episode 106.000000. Reward 17.333333. action: 1.000000. mean reward 19.665346.
# World Perf: Episode 109.000000. Reward 39.000000. action: 0.000000. mean reward 19.775578.
# World Perf: Episode 112.000000. Reward 28.000000. action: 1.000000. mean reward 19.758272.
# World Perf: Episode 115.000000. Reward 25.666667. action: 0.000000. mean reward 19.686140.
# World Perf: Episode 118.000000. Reward 18.000000. action: 0.000000. mean reward 19.621630.
# World Perf: Episode 121.000000. Reward 20.333333. action: 1.000000. mean reward 19.534313.
# World Perf: Episode 124.000000. Reward 11.666667. action: 1.000000. mean reward 19.335361.
# World Perf: Episode 127.000000. Reward 21.000000. action: 0.000000. mean reward 19.245123.
# World Perf: Episode 130.000000. Reward 28.333333. action: 0.000000. mean reward 19.468756.
# World Perf: Episode 133.000000. Reward 23.666667. action: 0.000000. mean reward 19.484610.
# World Perf: Episode 136.000000. Reward 13.333333. action: 0.000000. mean reward 20.889727.
# World Perf: Episode 139.000000. Reward 15.000000. action: 0.000000. mean reward 20.734951.
# World Perf: Episode 142.000000. Reward 20.333333. action: 0.000000. mean reward 20.746870.
# World Perf: Episode 145.000000. Reward 25.333333. action: 1.000000. mean reward 20.699036.
# World Perf: Episode 148.000000. Reward 39.333333. action: 0.000000. mean reward 21.192167.
# World Perf: Episode 151.000000. Reward 32.333333. action: 0.000000. mean reward 21.234869.
# World Perf: Episode 154.000000. Reward 34.666667. action: 0.000000. mean reward 21.402328.
# World Perf: Episode 157.000000. Reward 18.333333. action: 0.000000. mean reward 21.237974.
# World Perf: Episode 160.000000. Reward 15.666667. action: 1.000000. mean reward 21.022749.
# World Perf: Episode 163.000000. Reward 28.666667. action: 0.000000. mean reward 20.965151.
# World Perf: Episode 166.000000. Reward 23.666667. action: 1.000000. mean reward 21.266537.
# World Perf: Episode 169.000000. Reward 25.000000. action: 0.000000. mean reward 21.235214.
# World Perf: Episode 172.000000. Reward 17.333333. action: 0.000000. mean reward 21.162153.
# World Perf: Episode 175.000000. Reward 18.333333. action: 0.000000. mean reward 23.677824.
# World Perf: Episode 178.000000. Reward 20.666667. action: 0.000000. mean reward 23.538267.
# World Perf: Episode 181.000000. Reward 24.666667. action: 0.000000. mean reward 23.368416.
# World Perf: Episode 184.000000. Reward 23.666667. action: 1.000000. mean reward 23.207794.
# World Perf: Episode 187.000000. Reward 28.000000. action: 0.000000. mean reward 23.146749.
# World Perf: Episode 190.000000. Reward 35.666667. action: 0.000000. mean reward 23.274729.
# World Perf: Episode 193.000000. Reward 36.666667. action: 0.000000. mean reward 24.679831.
# World Perf: Episode 196.000000. Reward 26.666667. action: 0.000000. mean reward 24.525454.
# World Perf: Episode 199.000000. Reward 26.333333. action: 1.000000. mean reward 24.890244.
# World Perf: Episode 202.000000. Reward 45.666667. action: 1.000000. mean reward 25.018341.
# World Perf: Episode 205.000000. Reward 20.000000. action: 0.000000. mean reward 24.820808.
# World Perf: Episode 208.000000. Reward 31.333333. action: 0.000000. mean reward 24.703238.
# World Perf: Episode 211.000000. Reward 38.000000. action: 0.000000. mean reward 27.630432.
# World Perf: Episode 214.000000. Reward 37.000000. action: 0.000000. mean reward 27.534540.
# World Perf: Episode 217.000000. Reward 34.000000. action: 0.000000. mean reward 29.377901.
# World Perf: Episode 220.000000. Reward 20.666667. action: 0.000000. mean reward 30.103998.
# World Perf: Episode 223.000000. Reward 43.666667. action: 1.000000. mean reward 30.004580.
# World Perf: Episode 226.000000. Reward 26.333333. action: 1.000000. mean reward 29.886755.
# World Perf: Episode 229.000000. Reward 30.000000. action: 0.000000. mean reward 29.892916.
# World Perf: Episode 232.000000. Reward 31.666667. action: 0.000000. mean reward 29.681107.
# World Perf: Episode 235.000000. Reward 25.666667. action: 1.000000. mean reward 29.546614.
# World Perf: Episode 238.000000. Reward 39.333333. action: 1.000000. mean reward 29.457987.
# World Perf: Episode 241.000000. Reward 24.666667. action: 1.000000. mean reward 29.310028.
# World Perf: Episode 244.000000. Reward 27.666667. action: 0.000000. mean reward 29.427397.
# World Perf: Episode 247.000000. Reward 29.666667. action: 0.000000. mean reward 29.918175.
# World Perf: Episode 250.000000. Reward 36.333333. action: 0.000000. mean reward 29.821159.
# World Perf: Episode 253.000000. Reward 24.333333. action: 1.000000. mean reward 29.918962.
# World Perf: Episode 256.000000. Reward 53.666667. action: 0.000000. mean reward 30.020887.
# World Perf: Episode 259.000000. Reward 32.000000. action: 1.000000. mean reward 29.924309.
# World Perf: Episode 262.000000. Reward 27.000000. action: 0.000000. mean reward 29.707016.
# World Perf: Episode 265.000000. Reward 45.333333. action: 1.000000. mean reward 29.680597.
# World Perf: Episode 268.000000. Reward 38.000000. action: 0.000000. mean reward 29.625732.
# World Perf: Episode 271.000000. Reward 32.000000. action: 0.000000. mean reward 29.613533.
# World Perf: Episode 274.000000. Reward 46.000000. action: 1.000000. mean reward 29.628853.
# World Perf: Episode 277.000000. Reward 23.000000. action: 0.000000. mean reward 30.507902.
# World Perf: Episode 280.000000. Reward 21.666667. action: 0.000000. mean reward 30.233116.
# World Perf: Episode 283.000000. Reward 38.666667. action: 1.000000. mean reward 30.070139.
# World Perf: Episode 286.000000. Reward 32.333333. action: 1.000000. mean reward 29.979361.
# World Perf: Episode 289.000000. Reward 35.666667. action: 1.000000. mean reward 30.172134.
# World Perf: Episode 292.000000. Reward 17.666667. action: 0.000000. mean reward 29.923452.
# World Perf: Episode 295.000000. Reward 40.666667. action: 1.000000. mean reward 31.715660.
# World Perf: Episode 298.000000. Reward 37.000000. action: 1.000000. mean reward 31.641096.
# World Perf: Episode 301.000000. Reward 41.333333. action: 1.000000. mean reward 31.537910.
# World Perf: Episode 304.000000. Reward 31.333333. action: 1.000000. mean reward 31.554365.
# World Perf: Episode 307.000000. Reward 53.000000. action: 1.000000. mean reward 31.673716.
# World Perf: Episode 310.000000. Reward 25.000000. action: 1.000000. mean reward 31.852167.
# World Perf: Episode 313.000000. Reward 34.666667. action: 1.000000. mean reward 31.936821.
# World Perf: Episode 316.000000. Reward 72.666667. action: 1.000000. mean reward 32.135403.
# World Perf: Episode 319.000000. Reward 33.333333. action: 1.000000. mean reward 32.021461.
# World Perf: Episode 322.000000. Reward 37.333333. action: 0.000000. mean reward 32.027863.
# World Perf: Episode 325.000000. Reward 30.666667. action: 1.000000. mean reward 32.049820.
# World Perf: Episode 328.000000. Reward 18.333333. action: 0.000000. mean reward 31.724319.
# World Perf: Episode 331.000000. Reward 48.666667. action: 0.000000. mean reward 31.740042.
# World Perf: Episode 334.000000. Reward 38.666667. action: 1.000000. mean reward 33.887226.
# World Perf: Episode 337.000000. Reward 59.666667. action: 1.000000. mean reward 33.911560.
# World Perf: Episode 340.000000. Reward 47.666667. action: 1.000000. mean reward 36.932278.
# World Perf: Episode 343.000000. Reward 51.000000. action: 0.000000. mean reward 37.737411.
# World Perf: Episode 346.000000. Reward 28.666667. action: 0.000000. mean reward 37.439114.
# World Perf: Episode 349.000000. Reward 61.333333. action: 0.000000. mean reward 37.564461.
# World Perf: Episode 352.000000. Reward 15.000000. action: 0.000000. mean reward 37.308285.
# World Perf: Episode 355.000000. Reward 30.333333. action: 0.000000. mean reward 37.048588.
# World Perf: Episode 358.000000. Reward 57.333333. action: 1.000000. mean reward 36.952522.
# World Perf: Episode 361.000000. Reward 72.000000. action: 1.000000. mean reward 37.245613.
# World Perf: Episode 364.000000. Reward 30.666667. action: 0.000000. mean reward 39.966248.
# World Perf: Episode 367.000000. Reward 35.333333. action: 1.000000. mean reward 42.548222.
# World Perf: Episode 370.000000. Reward 45.333333. action: 0.000000. mean reward 42.272472.
# World Perf: Episode 373.000000. Reward 60.333333. action: 0.000000. mean reward 42.215092.
# World Perf: Episode 376.000000. Reward 58.666667. action: 1.000000. mean reward 42.063179.
# World Perf: Episode 379.000000. Reward 88.666667. action: 0.000000. mean reward 42.169750.
# World Perf: Episode 382.000000. Reward 69.333333. action: 0.000000. mean reward 42.124992.
# World Perf: Episode 385.000000. Reward 27.666667. action: 1.000000. mean reward 46.800152.
# World Perf: Episode 388.000000. Reward 55.000000. action: 1.000000. mean reward 46.507694.
# World Perf: Episode 391.000000. Reward 41.000000. action: 1.000000. mean reward 46.042225.
# World Perf: Episode 394.000000. Reward 31.000000. action: 1.000000. mean reward 50.847305.
# World Perf: Episode 397.000000. Reward 28.333333. action: 0.000000. mean reward 55.946198.
# World Perf: Episode 400.000000. Reward 55.000000. action: 1.000000. mean reward 55.463818.
# World Perf: Episode 403.000000. Reward 48.333333. action: 0.000000. mean reward 60.354691.
# World Perf: Episode 406.000000. Reward 80.666667. action: 1.000000. mean reward 62.287167.
# World Perf: Episode 409.000000. Reward 25.666667. action: 1.000000. mean reward 61.401806.
# World Perf: Episode 412.000000. Reward 33.666667. action: 0.000000. mean reward 60.807983.
# World Perf: Episode 415.000000. Reward 37.666667. action: 1.000000. mean reward 60.106449.
# World Perf: Episode 418.000000. Reward 27.000000. action: 1.000000. mean reward 59.469955.
# World Perf: Episode 421.000000. Reward 47.333333. action: 1.000000. mean reward 60.717831.
# World Perf: Episode 424.000000. Reward 56.333333. action: 1.000000. mean reward 61.937088.
# World Perf: Episode 427.000000. Reward 60.000000. action: 1.000000. mean reward 61.393478.
# World Perf: Episode 430.000000. Reward 42.666667. action: 1.000000. mean reward 60.713795.
# World Perf: Episode 433.000000. Reward 36.666667. action: 1.000000. mean reward 62.855358.
# World Perf: Episode 436.000000. Reward 29.333333. action: 1.000000. mean reward 63.341717.
# World Perf: Episode 439.000000. Reward 74.333333. action: 0.000000. mean reward 65.532982.
# World Perf: Episode 442.000000. Reward 74.000000. action: 1.000000. mean reward 68.200188.
# World Perf: Episode 445.000000. Reward 63.666667. action: 0.000000. mean reward 69.711281.
# World Perf: Episode 448.000000. Reward 77.000000. action: 0.000000. mean reward 69.147545.
# World Perf: Episode 451.000000. Reward 40.333333. action: 1.000000. mean reward 69.164856.
# World Perf: Episode 454.000000. Reward 100.333333. action: 0.000000. mean reward 71.088470.
# World Perf: Episode 457.000000. Reward 34.000000. action: 1.000000. mean reward 70.120399.
# World Perf: Episode 460.000000. Reward 36.333333. action: 0.000000. mean reward 69.903465.
# World Perf: Episode 463.000000. Reward 36.333333. action: 0.000000. mean reward 71.704803.
# World Perf: Episode 466.000000. Reward 28.666667. action: 0.000000. mean reward 70.666199.
# World Perf: Episode 469.000000. Reward 41.333333. action: 1.000000. mean reward 69.741447.
# World Perf: Episode 472.000000. Reward 46.333333. action: 1.000000. mean reward 69.110962.
# World Perf: Episode 475.000000. Reward 60.666667. action: 1.000000. mean reward 68.406708.
# World Perf: Episode 478.000000. Reward 72.000000. action: 1.000000. mean reward 67.959061.
# World Perf: Episode 481.000000. Reward 63.000000. action: 0.000000. mean reward 68.075325.
# World Perf: Episode 484.000000. Reward 90.666667. action: 0.000000. mean reward 68.030006.
# World Perf: Episode 487.000000. Reward 78.333333. action: 0.000000. mean reward 67.616844.
# World Perf: Episode 490.000000. Reward 41.000000. action: 0.000000. mean reward 70.246750.
# World Perf: Episode 493.000000. Reward 93.333333. action: 0.000000. mean reward 73.090202.
# World Perf: Episode 496.000000. Reward 66.333333. action: 1.000000. mean reward 72.422791.
# World Perf: Episode 499.000000. Reward 65.333333. action: 1.000000. mean reward 71.759361.
# World Perf: Episode 502.000000. Reward 111.000000. action: 1.000000. mean reward 71.541931.
# World Perf: Episode 505.000000. Reward 114.000000. action: 0.000000. mean reward 74.507111.
# World Perf: Episode 508.000000. Reward 74.333333. action: 0.000000. mean reward 73.977936.
# World Perf: Episode 511.000000. Reward 72.666667. action: 1.000000. mean reward 73.362137.
# World Perf: Episode 514.000000. Reward 116.666667. action: 0.000000. mean reward 73.388145.
# World Perf: Episode 517.000000. Reward 41.000000. action: 1.000000. mean reward 72.676285.
# World Perf: Episode 520.000000. Reward 48.666667. action: 0.000000. mean reward 71.922279.
# World Perf: Episode 523.000000. Reward 62.333333. action: 0.000000. mean reward 71.554764.
# World Perf: Episode 526.000000. Reward 79.000000. action: 1.000000. mean reward 70.985649.
# World Perf: Episode 529.000000. Reward 90.333333. action: 0.000000. mean reward 73.412666.
# World Perf: Episode 532.000000. Reward 112.000000. action: 0.000000. mean reward 73.210770.
# World Perf: Episode 535.000000. Reward 88.666667. action: 1.000000. mean reward 72.711121.
# World Perf: Episode 538.000000. Reward 110.000000. action: 0.000000. mean reward 72.419746.
# World Perf: Episode 541.000000. Reward 58.333333. action: 0.000000. mean reward 71.965187.
# World Perf: Episode 544.000000. Reward 74.000000. action: 0.000000. mean reward 71.321228.
# World Perf: Episode 547.000000. Reward 85.000000. action: 0.000000. mean reward 70.839401.
# World Perf: Episode 550.000000. Reward 127.333333. action: 0.000000. mean reward 70.847198.
# World Perf: Episode 553.000000. Reward 97.666667. action: 1.000000. mean reward 70.462746.
# World Perf: Episode 556.000000. Reward 69.333333. action: 1.000000. mean reward 69.860573.
# World Perf: Episode 559.000000. Reward 86.333333. action: 0.000000. mean reward 69.397301.
# World Perf: Episode 562.000000. Reward 49.000000. action: 0.000000. mean reward 72.814934.
# World Perf: Episode 565.000000. Reward 118.666667. action: 1.000000. mean reward 72.644279.
# World Perf: Episode 568.000000. Reward 115.000000. action: 1.000000. mean reward 72.469803.
# World Perf: Episode 571.000000. Reward 75.333333. action: 1.000000. mean reward 71.868393.
# World Perf: Episode 574.000000. Reward 85.333333. action: 0.000000. mean reward 72.663628.
# World Perf: Episode 577.000000. Reward 127.000000. action: 0.000000. mean reward 74.788300.
# World Perf: Episode 580.000000. Reward 137.666667. action: 0.000000. mean reward 74.822594.
# World Perf: Episode 583.000000. Reward 89.000000. action: 1.000000. mean reward 74.469147.
# World Perf: Episode 586.000000. Reward 70.666667. action: 0.000000. mean reward 76.598717.
# World Perf: Episode 589.000000. Reward 98.333333. action: 1.000000. mean reward 76.220833.
# World Perf: Episode 592.000000. Reward 118.333333. action: 0.000000. mean reward 76.521576.
# World Perf: Episode 595.000000. Reward 85.666667. action: 0.000000. mean reward 76.179626.
# World Perf: Episode 598.000000. Reward 111.666667. action: 1.000000. mean reward 78.818886.
# World Perf: Episode 601.000000. Reward 89.333333. action: 0.000000. mean reward 81.304825.
# World Perf: Episode 604.000000. Reward 69.333333. action: 1.000000. mean reward 81.728493.
# World Perf: Episode 607.000000. Reward 67.000000. action: 0.000000. mean reward 81.378273.
# World Perf: Episode 610.000000. Reward 59.000000. action: 0.000000. mean reward 80.689247.
# World Perf: Episode 613.000000. Reward 43.000000. action: 0.000000. mean reward 80.265785.
# World Perf: Episode 616.000000. Reward 83.333333. action: 1.000000. mean reward 79.812668.
# World Perf: Episode 619.000000. Reward 111.333333. action: 1.000000. mean reward 82.352066.
# World Perf: Episode 622.000000. Reward 132.666667. action: 0.000000. mean reward 82.506691.
# World Perf: Episode 625.000000. Reward 98.333333. action: 0.000000. mean reward 82.133186.
# World Perf: Episode 628.000000. Reward 76.000000. action: 0.000000. mean reward 81.418373.
# World Perf: Episode 631.000000. Reward 129.333333. action: 0.000000. mean reward 82.349190.
# World Perf: Episode 634.000000. Reward 91.333333. action: 1.000000. mean reward 82.468109.
# World Perf: Episode 637.000000. Reward 75.000000. action: 0.000000. mean reward 84.081055.
# World Perf: Episode 640.000000. Reward 88.000000. action: 0.000000. mean reward 84.865196.
# World Perf: Episode 643.000000. Reward 74.333333. action: 0.000000. mean reward 84.085220.
# World Perf: Episode 646.000000. Reward 110.333333. action: 0.000000. mean reward 86.430916.
# World Perf: Episode 649.000000. Reward 70.666667. action: 0.000000. mean reward 85.918114.
# World Perf: Episode 652.000000. Reward 86.000000. action: 1.000000. mean reward 85.197304.
# World Perf: Episode 655.000000. Reward 107.000000. action: 0.000000. mean reward 84.886063.
# World Perf: Episode 658.000000. Reward 106.666667. action: 0.000000. mean reward 84.517448.
# World Perf: Episode 661.000000. Reward 113.666667. action: 0.000000. mean reward 85.197647.
# World Perf: Episode 664.000000. Reward 83.333333. action: 0.000000. mean reward 84.500313.
# World Perf: Episode 667.000000. Reward 134.000000. action: 0.000000. mean reward 84.371902.
# World Perf: Episode 670.000000. Reward 46.000000. action: 1.000000. mean reward 83.521835.
# World Perf: Episode 673.000000. Reward 126.333333. action: 1.000000. mean reward 83.375038.
# World Perf: Episode 676.000000. Reward 133.333333. action: 0.000000. mean reward 83.168259.
# World Perf: Episode 679.000000. Reward 89.333333. action: 1.000000. mean reward 82.756622.
# World Perf: Episode 682.000000. Reward 128.333333. action: 0.000000. mean reward 82.757683.
# World Perf: Episode 685.000000. Reward 161.333333. action: 1.000000. mean reward 83.026894.
# World Perf: Episode 688.000000. Reward 113.000000. action: 0.000000. mean reward 83.469116.
# World Perf: Episode 691.000000. Reward 90.000000. action: 1.000000. mean reward 83.195862.
# World Perf: Episode 694.000000. Reward 84.333333. action: 1.000000. mean reward 82.502136.
# World Perf: Episode 697.000000. Reward 144.666667. action: 0.000000. mean reward 82.722008.
# World Perf: Episode 700.000000. Reward 91.666667. action: 1.000000. mean reward 82.192894.
# World Perf: Episode 703.000000. Reward 118.333333. action: 0.000000. mean reward 81.879364.
# World Perf: Episode 706.000000. Reward 145.000000. action: 0.000000. mean reward 81.989708.
# World Perf: Episode 709.000000. Reward 166.666667. action: 1.000000. mean reward 83.181717.
# World Perf: Episode 712.000000. Reward 58.000000. action: 0.000000. mean reward 82.279533.
# World Perf: Episode 715.000000. Reward 166.666667. action: 0.000000. mean reward 83.424271.
# World Perf: Episode 718.000000. Reward 148.000000. action: 0.000000. mean reward 83.472870.
# World Perf: Episode 721.000000. Reward 94.666667. action: 0.000000. mean reward 83.607178.
# World Perf: Episode 724.000000. Reward 150.000000. action: 1.000000. mean reward 83.689758.
# World Perf: Episode 727.000000. Reward 123.000000. action: 0.000000. mean reward 86.204399.
# World Perf: Episode 730.000000. Reward 100.333333. action: 1.000000. mean reward 85.638069.
# World Perf: Episode 733.000000. Reward 142.000000. action: 0.000000. mean reward 85.452065.
# World Perf: Episode 736.000000. Reward 113.000000. action: 1.000000. mean reward 85.072014.
# World Perf: Episode 739.000000. Reward 199.000000. action: 1.000000. mean reward 85.579536.
# World Perf: Episode 742.000000. Reward 200.000000. action: 1.000000. mean reward 85.971291.
# World Perf: Episode 745.000000. Reward 123.000000. action: 1.000000. mean reward 85.996468.
# World Perf: Episode 748.000000. Reward 174.333333. action: 1.000000. mean reward 86.229729.
# World Perf: Episode 751.000000. Reward 177.666667. action: 0.000000. mean reward 86.604408.
# World Perf: Episode 754.000000. Reward 95.666667. action: 1.000000. mean reward 86.044312.
# World Perf: Episode 757.000000. Reward 105.000000. action: 0.000000. mean reward 87.646095.
# World Perf: Episode 760.000000. Reward 200.000000. action: 0.000000. mean reward 90.934547.
# World Perf: Episode 763.000000. Reward 106.333333. action: 1.000000. mean reward 90.486816.
# World Perf: Episode 766.000000. Reward 177.333333. action: 1.000000. mean reward 90.811890.
# World Perf: Episode 769.000000. Reward 168.333333. action: 0.000000. mean reward 91.456108.
# World Perf: Episode 772.000000. Reward 137.000000. action: 1.000000. mean reward 93.961617.
# World Perf: Episode 775.000000. Reward 162.000000. action: 1.000000. mean reward 96.114861.
# World Perf: Episode 778.000000. Reward 136.333333. action: 0.000000. mean reward 95.911255.
# World Perf: Episode 781.000000. Reward 93.333333. action: 1.000000. mean reward 96.209557.
# World Perf: Episode 784.000000. Reward 167.666667. action: 0.000000. mean reward 96.425911.
# World Perf: Episode 787.000000. Reward 175.333333. action: 0.000000. mean reward 96.551727.
# World Perf: Episode 790.000000. Reward 166.666667. action: 1.000000. mean reward 97.822105.
# World Perf: Episode 793.000000. Reward 153.666667. action: 1.000000. mean reward 98.067574.
# World Perf: Episode 796.000000. Reward 106.333333. action: 0.000000. mean reward 97.450935.
# World Perf: Episode 799.000000. Reward 163.000000. action: 0.000000. mean reward 97.773018.
# World Perf: Episode 802.000000. Reward 108.666667. action: 1.000000. mean reward 97.515137.
# World Perf: Episode 805.000000. Reward 156.000000. action: 0.000000. mean reward 98.178902.
# World Perf: Episode 808.000000. Reward 200.000000. action: 0.000000. mean reward 101.130135.
# World Perf: Episode 811.000000. Reward 200.000000. action: 0.000000. mean reward 104.150566.
# World Perf: Episode 814.000000. Reward 122.000000. action: 0.000000. mean reward 103.484612.
# World Perf: Episode 817.000000. Reward 163.000000. action: 1.000000. mean reward 103.871765.
# World Perf: Episode 820.000000. Reward 137.666667. action: 0.000000. mean reward 106.671684.
# World Perf: Episode 823.000000. Reward 158.000000. action: 0.000000. mean reward 106.430229.
# World Perf: Episode 826.000000. Reward 200.000000. action: 0.000000. mean reward 106.604980.
# World Perf: Episode 829.000000. Reward 200.000000. action: 0.000000. mean reward 108.035927.
# World Perf: Episode 832.000000. Reward 182.333333. action: 1.000000. mean reward 110.646858.
# World Perf: Episode 835.000000. Reward 186.666667. action: 0.000000. mean reward 110.849968.
# World Perf: Episode 838.000000. Reward 177.333333. action: 0.000000. mean reward 112.946892.
# World Perf: Episode 841.000000. Reward 153.000000. action: 1.000000. mean reward 112.374092.
# World Perf: Episode 844.000000. Reward 117.333333. action: 1.000000. mean reward 113.562843.
# World Perf: Episode 847.000000. Reward 143.000000. action: 0.000000. mean reward 115.420555.
# World Perf: Episode 850.000000. Reward 136.333333. action: 1.000000. mean reward 115.409119.
# World Perf: Episode 853.000000. Reward 154.666667. action: 0.000000. mean reward 117.567055.
# World Perf: Episode 856.000000. Reward 103.333333. action: 0.000000. mean reward 118.921143.
# World Perf: Episode 859.000000. Reward 150.000000. action: 1.000000. mean reward 119.981689.
# World Perf: Episode 862.000000. Reward 151.666667. action: 0.000000. mean reward 122.605652.
# World Perf: Episode 865.000000. Reward 200.000000. action: 0.000000. mean reward 124.360435.
# World Perf: Episode 868.000000. Reward 129.666667. action: 0.000000. mean reward 123.344208.
# World Perf: Episode 871.000000. Reward 146.666667. action: 1.000000. mean reward 122.999397.
# World Perf: Episode 874.000000. Reward 200.000000. action: 0.000000. mean reward 126.093590.
# World Perf: Episode 877.000000. Reward 196.333333. action: 1.000000. mean reward 127.786522.
# World Perf: Episode 880.000000. Reward 200.000000. action: 0.000000. mean reward 127.345428.
# World Perf: Episode 883.000000. Reward 174.333333. action: 0.000000. mean reward 129.638290.
# World Perf: Episode 886.000000. Reward 200.000000. action: 0.000000. mean reward 129.492844.
# World Perf: Episode 889.000000. Reward 132.666667. action: 1.000000. mean reward 131.140457.
# World Perf: Episode 892.000000. Reward 200.000000. action: 0.000000. mean reward 133.453979.
# World Perf: Episode 895.000000. Reward 200.000000. action: 1.000000. mean reward 134.732956.
# World Perf: Episode 898.000000. Reward 200.000000. action: 1.000000. mean reward 134.402100.
# World Perf: Episode 901.000000. Reward 200.000000. action: 1.000000. mean reward 136.729370.
# World Perf: Episode 904.000000. Reward 200.000000. action: 1.000000. mean reward 137.163040.
# World Perf: Episode 907.000000. Reward 155.000000. action: 1.000000. mean reward 137.923508.
# World Perf: Episode 910.000000. Reward 188.666667. action: 1.000000. mean reward 140.056107.
# World Perf: Episode 913.000000. Reward 172.666667. action: 0.000000. mean reward 139.262527.
# World Perf: Episode 916.000000. Reward 200.000000. action: 1.000000. mean reward 140.768311.
# World Perf: Episode 919.000000. Reward 189.333333. action: 1.000000. mean reward 142.789810.
# World Perf: Episode 922.000000. Reward 200.000000. action: 1.000000. mean reward 144.899902.
# World Perf: Episode 925.000000. Reward 200.000000. action: 1.000000. mean reward 144.335922.
# World Perf: Episode 928.000000. Reward 166.333333. action: 0.000000. mean reward 143.365036.
# World Perf: Episode 931.000000. Reward 186.333333. action: 1.000000. mean reward 145.292770.
# World Perf: Episode 934.000000. Reward 184.000000. action: 1.000000. mean reward 146.662369.
# World Perf: Episode 937.000000. Reward 182.666667. action: 1.000000. mean reward 145.793228.
# World Perf: Episode 940.000000. Reward 183.333333. action: 0.000000. mean reward 144.825394.
# World Perf: Episode 943.000000. Reward 172.000000. action: 0.000000. mean reward 143.811661.
# World Perf: Episode 946.000000. Reward 177.666667. action: 0.000000. mean reward 145.171936.
# World Perf: Episode 949.000000. Reward 191.666667. action: 1.000000. mean reward 144.464127.
# World Perf: Episode 952.000000. Reward 151.000000. action: 0.000000. mean reward 143.387558.
# World Perf: Episode 955.000000. Reward 149.000000. action: 0.000000. mean reward 144.869019.
# World Perf: Episode 958.000000. Reward 173.000000. action: 1.000000. mean reward 146.592377.
# World Perf: Episode 961.000000. Reward 200.000000. action: 0.000000. mean reward 145.824081.
# World Perf: Episode 964.000000. Reward 175.666667. action: 0.000000. mean reward 144.965775.
# World Perf: Episode 967.000000. Reward 166.333333. action: 0.000000. mean reward 143.874817.
# World Perf: Episode 970.000000. Reward 147.666667. action: 0.000000. mean reward 142.788376.
# World Perf: Episode 973.000000. Reward 200.000000. action: 0.000000. mean reward 142.165237.
# World Perf: Episode 976.000000. Reward 156.666667. action: 1.000000. mean reward 145.808395.
# World Perf: Episode 979.000000. Reward 200.000000. action: 1.000000. mean reward 145.043137.
# World Perf: Episode 982.000000. Reward 200.000000. action: 0.000000. mean reward 145.282379.
# World Perf: Episode 985.000000. Reward 200.000000. action: 0.000000. mean reward 144.691223.
# World Perf: Episode 988.000000. Reward 180.000000. action: 1.000000. mean reward 143.906815.
# World Perf: Episode 991.000000. Reward 165.666667. action: 0.000000. mean reward 145.549118.
# World Perf: Episode 994.000000. Reward 200.000000. action: 1.000000. mean reward 147.156830.
# World Perf: Episode 997.000000. Reward 147.333333. action: 1.000000. mean reward 148.771439.
# World Perf: Episode 1000.000000. Reward 184.666667. action: 0.000000. mean reward 148.144913.
# World Perf: Episode 1003.000000. Reward 200.000000. action: 0.000000. mean reward 147.527206.
# World Perf: Episode 1006.000000. Reward 194.000000. action: 0.000000. mean reward 148.574692.
# World Perf: Episode 1009.000000. Reward 156.333333. action: 0.000000. mean reward 149.618759.
# World Perf: Episode 1012.000000. Reward 178.666667. action: 0.000000. mean reward 148.936661.
# World Perf: Episode 1015.000000. Reward 161.000000. action: 0.000000. mean reward 149.039032.
# World Perf: Episode 1018.000000. Reward 154.666667. action: 1.000000. mean reward 148.826935.
# World Perf: Episode 1021.000000. Reward 164.000000. action: 0.000000. mean reward 150.484818.
# World Perf: Episode 1024.000000. Reward 178.333333. action: 0.000000. mean reward 150.029892.
# World Perf: Episode 1027.000000. Reward 200.000000. action: 0.000000. mean reward 150.482254.
# World Perf: Episode 1030.000000. Reward 200.000000. action: 1.000000. mean reward 151.483475.
# World Perf: Episode 1033.000000. Reward 200.000000. action: 1.000000. mean reward 151.080246.
# World Perf: Episode 1036.000000. Reward 167.000000. action: 0.000000. mean reward 152.677536.
# World Perf: Episode 1039.000000. Reward 200.000000. action: 1.000000. mean reward 152.083145.
# World Perf: Episode 1042.000000. Reward 175.333333. action: 1.000000. mean reward 151.889420.
# World Perf: Episode 1045.000000. Reward 200.000000. action: 1.000000. mean reward 152.170166.
# World Perf: Episode 1048.000000. Reward 200.000000. action: 0.000000. mean reward 152.171005.
# World Perf: Episode 1051.000000. Reward 195.666667. action: 0.000000. mean reward 154.055069.
# World Perf: Episode 1054.000000. Reward 200.000000. action: 1.000000. mean reward 154.064545.
# World Perf: Episode 1057.000000. Reward 167.333333. action: 0.000000. mean reward 153.512497.
# World Perf: Episode 1060.000000. Reward 200.000000. action: 0.000000. mean reward 155.253342.
# World Perf: Episode 1063.000000. Reward 158.333333. action: 0.000000. mean reward 155.780518.
# World Perf: Episode 1066.000000. Reward 180.666667. action: 0.000000. mean reward 157.443817.
# World Perf: Episode 1069.000000. Reward 173.000000. action: 0.000000. mean reward 158.417953.
# World Perf: Episode 1072.000000. Reward 161.666667. action: 0.000000. mean reward 159.196732.
# World Perf: Episode 1075.000000. Reward 197.666667. action: 0.000000. mean reward 159.129700.
# World Perf: Episode 1078.000000. Reward 200.000000. action: 0.000000. mean reward 158.413788.
# World Perf: Episode 1081.000000. Reward 199.000000. action: 1.000000. mean reward 159.578995.
# World Perf: Episode 1084.000000. Reward 200.000000. action: 0.000000. mean reward 161.337479.
# World Perf: Episode 1087.000000. Reward 200.000000. action: 1.000000. mean reward 160.688065.
# World Perf: Episode 1090.000000. Reward 200.000000. action: 1.000000. mean reward 159.765732.
# World Perf: Episode 1093.000000. Reward 200.000000. action: 1.000000. mean reward 161.634628.
# World Perf: Episode 1096.000000. Reward 200.000000. action: 1.000000. mean reward 161.019730.
# World Perf: Episode 1099.000000. Reward 200.000000. action: 0.000000. mean reward 160.124023.
# World Perf: Episode 1102.000000. Reward 200.000000. action: 1.000000. mean reward 160.388046.
# World Perf: Episode 1105.000000. Reward 200.000000. action: 0.000000. mean reward 162.442612.
# World Perf: Episode 1108.000000. Reward 188.666667. action: 1.000000. mean reward 163.401749.
# World Perf: Episode 1111.000000. Reward 200.000000. action: 0.000000. mean reward 163.703232.
# World Perf: Episode 1114.000000. Reward 200.000000. action: 1.000000. mean reward 164.889175.
# World Perf: Episode 1117.000000. Reward 198.333333. action: 1.000000. mean reward 164.467575.
# World Perf: Episode 1120.000000. Reward 200.000000. action: 1.000000. mean reward 163.726486.
# World Perf: Episode 1123.000000. Reward 200.000000. action: 0.000000. mean reward 165.163589.
# World Perf: Episode 1126.000000. Reward 196.333333. action: 1.000000. mean reward 164.199081.
# World Perf: Episode 1129.000000. Reward 174.000000. action: 0.000000. mean reward 164.775040.
# World Perf: Episode 1132.000000. Reward 200.000000. action: 1.000000. mean reward 166.461563.
# World Perf: Episode 1135.000000. Reward 200.000000. action: 1.000000. mean reward 167.302078.
# World Perf: Episode 1138.000000. Reward 200.000000. action: 0.000000. mean reward 166.287979.
# World Perf: Episode 1141.000000. Reward 186.666667. action: 0.000000. mean reward 166.004776.
# World Perf: Episode 1144.000000. Reward 200.000000. action: 0.000000. mean reward 165.777054.
# World Perf: Episode 1147.000000. Reward 194.000000. action: 1.000000. mean reward 165.007339.
# World Perf: Episode 1150.000000. Reward 200.000000. action: 1.000000. mean reward 164.244080.
# World Perf: Episode 1153.000000. Reward 200.000000. action: 0.000000. mean reward 165.994614.
# World Perf: Episode 1156.000000. Reward 199.666667. action: 1.000000. mean reward 167.673752.
# World Perf: Episode 1159.000000. Reward 200.000000. action: 0.000000. mean reward 169.267502.
# World Perf: Episode 1162.000000. Reward 200.000000. action: 1.000000. mean reward 169.895554.
# World Perf: Episode 1165.000000. Reward 200.000000. action: 1.000000. mean reward 169.741318.
# World Perf: Episode 1168.000000. Reward 200.000000. action: 1.000000. mean reward 170.932053.
# World Perf: Episode 1171.000000. Reward 200.000000. action: 0.000000. mean reward 170.505844.
# World Perf: Episode 1174.000000. Reward 200.000000. action: 0.000000. mean reward 170.239044.
# World Perf: Episode 1177.000000. Reward 200.000000. action: 0.000000. mean reward 170.680969.
# World Perf: Episode 1180.000000. Reward 126.333333. action: 0.000000. mean reward 170.681213.
# World Perf: Episode 1183.000000. Reward 200.000000. action: 0.000000. mean reward 169.823593.
# World Perf: Episode 1186.000000. Reward 154.666667. action: 1.000000. mean reward 168.524704.
# World Perf: Episode 1189.000000. Reward 181.000000. action: 0.000000. mean reward 167.363632.
# World Perf: Episode 1192.000000. Reward 200.000000. action: 1.000000. mean reward 166.447037.
# World Perf: Episode 1195.000000. Reward 200.000000. action: 0.000000. mean reward 166.099625.
# World Perf: Episode 1198.000000. Reward 200.000000. action: 1.000000. mean reward 165.569275.
# World Perf: Episode 1201.000000. Reward 180.333333. action: 1.000000. mean reward 164.457642.
# World Perf: Episode 1204.000000. Reward 200.000000. action: 1.000000. mean reward 166.178543.
# World Perf: Episode 1207.000000. Reward 200.000000. action: 0.000000. mean reward 167.862000.
# World Perf: Episode 1210.000000. Reward 200.000000. action: 0.000000. mean reward 169.471024.
# World Perf: Episode 1213.000000. Reward 200.000000. action: 1.000000. mean reward 169.486801.
# World Perf: Episode 1216.000000. Reward 187.333333. action: 0.000000. mean reward 170.246582.
# World Perf: Episode 1219.000000. Reward 179.333333. action: 1.000000. mean reward 171.638870.
# World Perf: Episode 1222.000000. Reward 200.000000. action: 1.000000. mean reward 173.192337.
# World Perf: Episode 1225.000000. Reward 200.000000. action: 1.000000. mean reward 174.738342.
# World Perf: Episode 1228.000000. Reward 200.000000. action: 1.000000. mean reward 173.981857.
# World Perf: Episode 1231.000000. Reward 161.000000. action: 0.000000. mean reward 173.781113.
# World Perf: Episode 1234.000000. Reward 175.666667. action: 1.000000. mean reward 173.823776.
# World Perf: Episode 1237.000000. Reward 200.000000. action: 1.000000. mean reward 173.635437.
# World Perf: Episode 1240.000000. Reward 200.000000. action: 1.000000. mean reward 175.161255.
# World Perf: Episode 1243.000000. Reward 200.000000. action: 1.000000. mean reward 175.296814.
# World Perf: Episode 1246.000000. Reward 200.000000. action: 1.000000. mean reward 176.770920.
# World Perf: Episode 1249.000000. Reward 171.333333. action: 0.000000. mean reward 177.943192.
# World Perf: Episode 1252.000000. Reward 200.000000. action: 0.000000. mean reward 178.358704.
# World Perf: Episode 1255.000000. Reward 200.000000. action: 0.000000. mean reward 179.772720.
# World Perf: Episode 1258.000000. Reward 180.000000. action: 0.000000. mean reward 180.649902.
# World Perf: Episode 1261.000000. Reward 200.000000. action: 0.000000. mean reward 179.717758.
# World Perf: Episode 1264.000000. Reward 200.000000. action: 0.000000. mean reward 181.115738.
# World Perf: Episode 1267.000000. Reward 200.000000. action: 1.000000. mean reward 181.595139.
# World Perf: Episode 1270.000000. Reward 200.000000. action: 0.000000. mean reward 182.950745.
# World Perf: Episode 1273.000000. Reward 200.000000. action: 1.000000. mean reward 183.394852.
# World Perf: Episode 1276.000000. Reward 200.000000. action: 0.000000. mean reward 183.880478.
# World Perf: Episode 1279.000000. Reward 200.000000. action: 1.000000. mean reward 185.005447.
# World Perf: Episode 1282.000000. Reward 200.000000. action: 0.000000. mean reward 186.277115.
# World Perf: Episode 1285.000000. Reward 200.000000. action: 1.000000. mean reward 186.675476.
# World Perf: Episode 1288.000000. Reward 200.000000. action: 1.000000. mean reward 186.077148.
# World Perf: Episode 1291.000000. Reward 200.000000. action: 1.000000. mean reward 186.354980.
# World Perf: Episode 1294.000000. Reward 200.000000. action: 0.000000. mean reward 185.012161.
# World Perf: Episode 1297.000000. Reward 200.000000. action: 1.000000. mean reward 184.572388.
# World Perf: Episode 1300.000000. Reward 200.000000. action: 0.000000. mean reward 185.872009.
# World Perf: Episode 1303.000000. Reward 200.000000. action: 0.000000. mean reward 187.145889.
# World Perf: Episode 1306.000000. Reward 200.000000. action: 0.000000. mean reward 186.875900.
# World Perf: Episode 1309.000000. Reward 200.000000. action: 0.000000. mean reward 186.742691.
# World Perf: Episode 1312.000000. Reward 200.000000. action: 1.000000. mean reward 188.014404.
# World Perf: Episode 1315.000000. Reward 200.000000. action: 1.000000. mean reward 189.254959.
# World Perf: Episode 1318.000000. Reward 200.000000. action: 1.000000. mean reward 188.849380.
# World Perf: Episode 1321.000000. Reward 200.000000. action: 1.000000. mean reward 187.553635.
# World Perf: Episode 1324.000000. Reward 200.000000. action: 1.000000. mean reward 186.469849.
# World Perf: Episode 1327.000000. Reward 200.000000. action: 1.000000. mean reward 185.537857.
# World Perf: Episode 1330.000000. Reward 193.000000. action: 1.000000. mean reward 185.128159.
# World Perf: Episode 1333.000000. Reward 200.000000. action: 0.000000. mean reward 184.987259.
# World Perf: Episode 1336.000000. Reward 200.000000. action: 0.000000. mean reward 184.560303.
# World Perf: Episode 1339.000000. Reward 167.666667. action: 0.000000. mean reward 183.020035.
# World Perf: Episode 1342.000000. Reward 200.000000. action: 0.000000. mean reward 183.611526.
# World Perf: Episode 1345.000000. Reward 200.000000. action: 1.000000. mean reward 183.418564.
# World Perf: Episode 1348.000000. Reward 200.000000. action: 1.000000. mean reward 183.261185.
# World Perf: Episode 1351.000000. Reward 200.000000. action: 1.000000. mean reward 184.578995.
# World Perf: Episode 1354.000000. Reward 200.000000. action: 1.000000. mean reward 185.871140.
# World Perf: Episode 1357.000000. Reward 164.666667. action: 0.000000. mean reward 186.766922.
# World Perf: Episode 1360.000000. Reward 200.000000. action: 1.000000. mean reward 186.317383.
# World Perf: Episode 1363.000000. Reward 200.000000. action: 0.000000. mean reward 187.574417.
# World Perf: Episode 1366.000000. Reward 200.000000. action: 1.000000. mean reward 188.792557.
# World Perf: Episode 1369.000000. Reward 200.000000. action: 0.000000. mean reward 187.542923.
# World Perf: Episode 1372.000000. Reward 200.000000. action: 1.000000. mean reward 186.320557.
# World Perf: Episode 1375.000000. Reward 200.000000. action: 0.000000. mean reward 185.226974.
# World Perf: Episode 1378.000000. Reward 200.000000. action: 0.000000. mean reward 184.930923.
# World Perf: Episode 1381.000000. Reward 200.000000. action: 1.000000. mean reward 186.183960.
# World Perf: Episode 1384.000000. Reward 200.000000. action: 1.000000. mean reward 186.746628.
# World Perf: Episode 1387.000000. Reward 200.000000. action: 1.000000. mean reward 187.441757.
# World Perf: Episode 1390.000000. Reward 200.000000. action: 1.000000. mean reward 188.672440.
# World Perf: Episode 1393.000000. Reward 200.000000. action: 1.000000. mean reward 189.122986.
# World Perf: Episode 1396.000000. Reward 200.000000. action: 0.000000. mean reward 190.333908.
# World Perf: Episode 1399.000000. Reward 200.000000. action: 1.000000. mean reward 191.529160.
# World Perf: Episode 1402.000000. Reward 200.000000. action: 1.000000. mean reward 191.124710.
# World Perf: Episode 1405.000000. Reward 200.000000. action: 1.000000. mean reward 192.350632.
# World Perf: Episode 1408.000000. Reward 200.000000. action: 1.000000. mean reward 192.543411.
# World Perf: Episode 1411.000000. Reward 200.000000. action: 0.000000. mean reward 193.676193.
# World Perf: Episode 1414.000000. Reward 200.000000. action: 0.000000. mean reward 194.805054.
# World Perf: Episode 1417.000000. Reward 200.000000. action: 0.000000. mean reward 195.382767.
# World Perf: Episode 1420.000000. Reward 200.000000. action: 0.000000. mean reward 194.866714.
# World Perf: Episode 1423.000000. Reward 200.000000. action: 1.000000. mean reward 195.962891.
# World Perf: Episode 1426.000000. Reward 199.333333. action: 1.000000. mean reward 196.119385.
# World Perf: Episode 1429.000000. Reward 200.000000. action: 0.000000. mean reward 195.218552.
# World Perf: Episode 1432.000000. Reward 192.000000. action: 0.000000. mean reward 196.229294.
# World Perf: Episode 1435.000000. Reward 200.000000. action: 1.000000. mean reward 196.817520.
# World Perf: Episode 1438.000000. Reward 200.000000. action: 1.000000. mean reward 196.498245.
# World Perf: Episode 1441.000000. Reward 200.000000. action: 1.000000. mean reward 197.352112.
# World Perf: Episode 1444.000000. Reward 198.333333. action: 1.000000. mean reward 196.422668.
# World Perf: Episode 1447.000000. Reward 200.000000. action: 0.000000. mean reward 197.053085.
# World Perf: Episode 1450.000000. Reward 200.000000. action: 0.000000. mean reward 198.100540.
# World Perf: Episode 1453.000000. Reward 200.000000. action: 1.000000. mean reward 198.297562.
# World Perf: Episode 1456.000000. Reward 200.000000. action: 1.000000. mean reward 197.978958.
# World Perf: Episode 1459.000000. Reward 200.000000. action: 0.000000. mean reward 198.997269.
# World Perf: Episode 1462.000000. Reward 200.000000. action: 0.000000. mean reward 197.590225.
# World Perf: Episode 1465.000000. Reward 200.000000. action: 1.000000. mean reward 198.639847.
# World Perf: Episode 1468.000000. Reward 200.000000. action: 0.000000. mean reward 199.662659.
# World Perf: Episode 1471.000000. Reward 200.000000. action: 0.000000. mean reward 198.747971.
# World Perf: Episode 1474.000000. Reward 200.000000. action: 0.000000. mean reward 199.773026.
# World Perf: Episode 1477.000000. Reward 200.000000. action: 0.000000. mean reward 200.178726.
# World Perf: Episode 1480.000000. Reward 200.000000. action: 0.000000. mean reward 201.180923.
# World Perf: Episode 1483.000000. Reward 200.000000. action: 0.000000. mean reward 200.092514.
# World Perf: Episode 1486.000000. Reward 187.333333. action: 0.000000. mean reward 200.940918.
# World Perf: Episode 1489.000000. Reward 200.000000. action: 0.000000. mean reward 199.817978.
# World Perf: Episode 1492.000000. Reward 190.333333. action: 0.000000. mean reward 200.262985.
# World Perf: Episode 1495.000000. Reward 200.000000. action: 1.000000. mean reward 200.902115.
# World Perf: Episode 1498.000000. Reward 200.000000. action: 1.000000. mean reward 199.296204.
# World Perf: Episode 1501.000000. Reward 200.000000. action: 1.000000. mean reward 198.255264.
# World Perf: Episode 1504.000000. Reward 200.000000. action: 1.000000. mean reward 196.962845.
# World Perf: Episode 1507.000000. Reward 200.000000. action: 0.000000. mean reward 195.640152.
# World Perf: Episode 1510.000000. Reward 200.000000. action: 1.000000. mean reward 194.433304.
# World Perf: Episode 1513.000000. Reward 200.000000. action: 1.000000. mean reward 193.249695.
# World Perf: Episode 1516.000000. Reward 200.000000. action: 1.000000. mean reward 193.555603.
# World Perf: Episode 1519.000000. Reward 200.000000. action: 1.000000. mean reward 193.308853.
# World Perf: Episode 1522.000000. Reward 200.000000. action: 0.000000. mean reward 192.372849.
# World Perf: Episode 1525.000000. Reward 162.000000. action: 1.000000. mean reward 192.810791.
# World Perf: Episode 1528.000000. Reward 200.000000. action: 0.000000. mean reward 193.388382.
# World Perf: Episode 1531.000000. Reward 200.000000. action: 1.000000. mean reward 194.506104.
# World Perf: Episode 1534.000000. Reward 200.000000. action: 1.000000. mean reward 195.488998.
# World Perf: Episode 1537.000000. Reward 200.000000. action: 0.000000. mean reward 194.673279.
# World Perf: Episode 1540.000000. Reward 176.333333. action: 1.000000. mean reward 193.644730.
# World Perf: Episode 1543.000000. Reward 200.000000. action: 1.000000. mean reward 194.019699.
# World Perf: Episode 1546.000000. Reward 200.000000. action: 1.000000. mean reward 194.408493.
# World Perf: Episode 1549.000000. Reward 200.000000. action: 1.000000. mean reward 195.141312.
# World Perf: Episode 1552.000000. Reward 192.666667. action: 1.000000. mean reward 194.822159.
# World Perf: Episode 1555.000000. Reward 200.000000. action: 0.000000. mean reward 194.960892.
# World Perf: Episode 1558.000000. Reward 200.000000. action: 1.000000. mean reward 195.477402.
# ...
# World Perf: Episode 2062.000000. Reward 200.000000. action: 0.000000. mean reward 203.977417.
# World Perf: Episode 2065.000000. Reward 200.000000. action: 1.000000. mean reward 204.945480.
# World Perf: Episode 2068.000000. Reward 200.000000. action: 1.000000. mean reward 203.759506.
# World Perf: Episode 2071.000000. Reward 200.000000. action: 0.000000. mean reward 203.855423.
# World Perf: Episode 2074.000000. Reward 200.000000. action: 0.000000. mean reward 204.845779.
# World Perf: Episode 2077.000000. Reward 200.000000. action: 1.000000. mean reward 203.217361.
# World Perf: Episode 2080.000000. Reward 200.000000. action: 0.000000. mean reward 202.831650.
# World Perf: Episode 2083.000000. Reward 199.000000. action: 1.000000. mean reward 203.247513.
# World Perf: Episode 2086.000000. Reward 200.000000. action: 0.000000. mean reward 204.143723.
# World Perf: Episode 2089.000000. Reward 200.000000. action: 0.000000. mean reward 205.099991.
# World Perf: Episode 2092.000000. Reward 200.000000. action: 1.000000. mean reward 203.926819.
# World Perf: Episode 2095.000000. Reward 200.000000. action: 1.000000. mean reward 204.980347.
# World Perf: Episode 2098.000000. Reward 200.000000. action: 1.000000. mean reward 205.921402.
# World Perf: Episode 2101.000000. Reward 200.000000. action: 0.000000. mean reward 205.073715.
# World Perf: Episode 2104.000000. Reward 200.000000. action: 1.000000. mean reward 205.856262.
# World Perf: Episode 2107.000000. Reward 200.000000. action: 0.000000. mean reward 206.766708.
# World Perf: Episode 2110.000000. Reward 200.000000. action: 1.000000. mean reward 207.576706.
# World Perf: Episode 2113.000000. Reward 200.000000. action: 1.000000. mean reward 208.331711.
# World Perf: Episode 2116.000000. Reward 200.000000. action: 1.000000. mean reward 207.957382.
# World Perf: Episode 2119.000000. Reward 200.000000. action: 1.000000. mean reward 208.735184.
# World Perf: Episode 2122.000000. Reward 200.000000. action: 0.000000. mean reward 209.599319.
# World Perf: Episode 2125.000000. Reward 200.000000. action: 1.000000. mean reward 209.280334.
# World Perf: Episode 2128.000000. Reward 200.000000. action: 1.000000. mean reward 210.081802.
# World Perf: Episode 2131.000000. Reward 200.000000. action: 0.000000. mean reward 210.874924.
# World Perf: Episode 2134.000000. Reward 200.000000. action: 0.000000. mean reward 211.662674.
# World Perf: Episode 2137.000000. Reward 200.000000. action: 0.000000. mean reward 212.514450.
# World Perf: Episode 2140.000000. Reward 200.000000. action: 0.000000. mean reward 213.270187.
# World Perf: Episode 2143.000000. Reward 200.000000. action: 0.000000. mean reward 214.025406.
# World Perf: Episode 2146.000000. Reward 200.000000. action: 0.000000. mean reward 214.691818.
# World Perf: Episode 2149.000000. Reward 200.000000. action: 1.000000. mean reward 215.408936.
# World Perf: Episode 2152.000000. Reward 200.000000. action: 1.000000. mean reward 216.078735.
# World Perf: Episode 2155.000000. Reward 200.000000. action: 1.000000. mean reward 216.740707.
# World Perf: Episode 2158.000000. Reward 200.000000. action: 1.000000. mean reward 217.425415.
# World Perf: Episode 2161.000000. Reward 200.000000. action: 1.000000. mean reward 215.640686.
# World Perf: Episode 2164.000000. Reward 200.000000. action: 1.000000. mean reward 216.321396.
# World Perf: Episode 2167.000000. Reward 200.000000. action: 1.000000. mean reward 216.982712.
# World Perf: Episode 2170.000000. Reward 200.000000. action: 0.000000. mean reward 217.620285.
# World Perf: Episode 2173.000000. Reward 200.000000. action: 0.000000. mean reward 217.768814.
# World Perf: Episode 2176.000000. Reward 200.000000. action: 0.000000. mean reward 215.935654.
# World Perf: Episode 2179.000000. Reward 196.000000. action: 0.000000. mean reward 216.798523.
# World Perf: Episode 2182.000000. Reward 200.000000. action: 1.000000. mean reward 217.388550.
# World Perf: Episode 2185.000000. Reward 200.000000. action: 1.000000. mean reward 218.190308.
# World Perf: Episode 2188.000000. Reward 200.000000. action: 1.000000. mean reward 219.226395.
# World Perf: Episode 2191.000000. Reward 200.000000. action: 1.000000. mean reward 219.934830.
# World Perf: Episode 2194.000000. Reward 200.000000. action: 0.000000. mean reward 217.952805.
# World Perf: Episode 2197.000000. Reward 200.000000. action: 1.000000. mean reward 218.617935.
# World Perf: Episode 2200.000000. Reward 200.000000. action: 0.000000. mean reward 218.369492.
# World Perf: Episode 2203.000000. Reward 196.666667. action: 1.000000. mean reward 218.293320.
# World Perf: Episode 2206.000000. Reward 200.000000. action: 1.000000. mean reward 218.950928.
# World Perf: Episode 2209.000000. Reward 200.000000. action: 1.000000. mean reward 219.352798.
# World Perf: Episode 2212.000000. Reward 148.333333. action: 1.000000. mean reward 218.895981.
# World Perf: Episode 2215.000000. Reward 200.000000. action: 1.000000. mean reward 217.489273.
# World Perf: Episode 2218.000000. Reward 200.000000. action: 1.000000. mean reward 218.088333.
# World Perf: Episode 2221.000000. Reward 200.000000. action: 0.000000. mean reward 216.819748.
# World Perf: Episode 2224.000000. Reward 200.000000. action: 1.000000. mean reward 216.008133.
# World Perf: Episode 2227.000000. Reward 200.000000. action: 1.000000. mean reward 216.756454.
# World Perf: Episode 2230.000000. Reward 200.000000. action: 1.000000. mean reward 215.038925.
# World Perf: Episode 2233.000000. Reward 200.000000. action: 0.000000. mean reward 215.816772.
# World Perf: Episode 2236.000000. Reward 200.000000. action: 1.000000. mean reward 214.734787.
# World Perf: Episode 2239.000000. Reward 200.000000. action: 1.000000. mean reward 212.928040.
# World Perf: Episode 2242.000000. Reward 193.000000. action: 1.000000. mean reward 213.670670.
# World Perf: Episode 2245.000000. Reward 200.000000. action: 1.000000. mean reward 211.747559.
# World Perf: Episode 2248.000000. Reward 195.000000. action: 0.000000. mean reward 212.685776.
# World Perf: Episode 2251.000000. Reward 196.666667. action: 0.000000. mean reward 213.369080.
# World Perf: Episode 2254.000000. Reward 200.000000. action: 0.000000. mean reward 213.328323.
# World Perf: Episode 2257.000000. Reward 200.000000. action: 1.000000. mean reward 214.059341.
# World Perf: Episode 2260.000000. Reward 196.666667. action: 1.000000. mean reward 214.093201.
# World Perf: Episode 2263.000000. Reward 200.000000. action: 0.000000. mean reward 214.927612.
# World Perf: Episode 2266.000000. Reward 200.000000. action: 1.000000. mean reward 214.613113.
# World Perf: Episode 2269.000000. Reward 200.000000. action: 0.000000. mean reward 214.803024.
# World Perf: Episode 2272.000000. Reward 200.000000. action: 0.000000. mean reward 215.526428.
# World Perf: Episode 2275.000000. Reward 200.000000. action: 1.000000. mean reward 216.238037.
# World Perf: Episode 2278.000000. Reward 195.000000. action: 1.000000. mean reward 216.836380.
# World Perf: Episode 2281.000000. Reward 200.000000. action: 1.000000. mean reward 215.599670.
# World Perf: Episode 2284.000000. Reward 200.000000. action: 0.000000. mean reward 216.041138.
# World Perf: Episode 2287.000000. Reward 200.000000. action: 1.000000. mean reward 216.691513.
# World Perf: Episode 2290.000000. Reward 200.000000. action: 1.000000. mean reward 217.368088.
# World Perf: Episode 2293.000000. Reward 192.000000. action: 1.000000. mean reward 217.937561.
# World Perf: Episode 2296.000000. Reward 175.666667. action: 0.000000. mean reward 217.591721.
# World Perf: Episode 2299.000000. Reward 200.000000. action: 0.000000. mean reward 215.751968.
# World Perf: Episode 2302.000000. Reward 200.000000. action: 1.000000. mean reward 215.173630.
# World Perf: Episode 2305.000000. Reward 200.000000. action: 0.000000. mean reward 216.943375.
# World Perf: Episode 2308.000000. Reward 200.000000. action: 1.000000. mean reward 215.952515.
# World Perf: Episode 2311.000000. Reward 199.333333. action: 1.000000. mean reward 217.957077.
# World Perf: Episode 2314.000000. Reward 200.000000. action: 0.000000. mean reward 217.279984.
# World Perf: Episode 2317.000000. Reward 200.000000. action: 0.000000. mean reward 215.907043.
# World Perf: Episode 2320.000000. Reward 191.000000. action: 1.000000. mean reward 216.443436.
# World Perf: Episode 2323.000000. Reward 200.000000. action: 1.000000. mean reward 217.058395.
# World Perf: Episode 2326.000000. Reward 200.000000. action: 1.000000. mean reward 214.931076.
# World Perf: Episode 2329.000000. Reward 190.333333. action: 0.000000. mean reward 216.485947.
# World Perf: Episode 2332.000000. Reward 200.000000. action: 0.000000. mean reward 214.343338.
# World Perf: Episode 2335.000000. Reward 187.000000. action: 1.000000. mean reward 212.457397.
# World Perf: Episode 2338.000000. Reward 200.000000. action: 0.000000. mean reward 213.230301.
# World Perf: Episode 2341.000000. Reward 182.333333. action: 1.000000. mean reward 212.275818.
# World Perf: Episode 2344.000000. Reward 199.000000. action: 0.000000. mean reward 212.933838.
# World Perf: Episode 2347.000000. Reward 200.000000. action: 0.000000. mean reward 214.165955.
# World Perf: Episode 2350.000000. Reward 200.000000. action: 1.000000. mean reward 212.070206.
# World Perf: Episode 2353.000000. Reward 194.666667. action: 1.000000. mean reward 214.202347.
# World Perf: Episode 2356.000000. Reward 200.000000. action: 1.000000. mean reward 212.713547.
# World Perf: Episode 2359.000000. Reward 200.000000. action: 1.000000. mean reward 210.770615.
# World Perf: Episode 2362.000000. Reward 200.000000. action: 1.000000. mean reward 211.116074.
# World Perf: Episode 2365.000000. Reward 200.000000. action: 0.000000. mean reward 211.786270.
# World Perf: Episode 2368.000000. Reward 200.000000. action: 1.000000. mean reward 211.653061.
# World Perf: Episode 2371.000000. Reward 200.000000. action: 1.000000. mean reward 212.563950.
# World Perf: Episode 2374.000000. Reward 200.000000. action: 0.000000. mean reward 213.532578.
# World Perf: Episode 2377.000000. Reward 200.000000. action: 1.000000. mean reward 211.491577.
# World Perf: Episode 2380.000000. Reward 200.000000. action: 1.000000. mean reward 211.480469.
# World Perf: Episode 2383.000000. Reward 200.000000. action: 0.000000. mean reward 209.422165.
# World Perf: Episode 2386.000000. Reward 190.000000. action: 1.000000. mean reward 207.706177.
# World Perf: Episode 2389.000000. Reward 200.000000. action: 0.000000. mean reward 208.484299.
# World Perf: Episode 2392.000000. Reward 192.000000. action: 1.000000. mean reward 209.150955.
# World Perf: Episode 2395.000000. Reward 190.666667. action: 0.000000. mean reward 208.073746.
# World Perf: Episode 2398.000000. Reward 200.000000. action: 1.000000. mean reward 207.129395.
# World Perf: Episode 2401.000000. Reward 197.000000. action: 0.000000. mean reward 208.026413.
# World Perf: Episode 2404.000000. Reward 200.000000. action: 1.000000. mean reward 208.890671.
# World Perf: Episode 2407.000000. Reward 200.000000. action: 1.000000. mean reward 209.715988.
# World Perf: Episode 2410.000000. Reward 200.000000. action: 0.000000. mean reward 210.488953.
# World Perf: Episode 2413.000000. Reward 200.000000. action: 1.000000. mean reward 211.310715.
# World Perf: Episode 2416.000000. Reward 200.000000. action: 0.000000. mean reward 212.072647.
# World Perf: Episode 2419.000000. Reward 200.000000. action: 1.000000. mean reward 212.795273.
# World Perf: Episode 2422.000000. Reward 200.000000. action: 0.000000. mean reward 211.166306.
# World Perf: Episode 2425.000000. Reward 188.000000. action: 0.000000. mean reward 211.817749.
# World Perf: Episode 2428.000000. Reward 180.000000. action: 0.000000. mean reward 212.380310.
# World Perf: Episode 2431.000000. Reward 200.000000. action: 1.000000. mean reward 213.129944.
# World Perf: Episode 2434.000000. Reward 200.000000. action: 1.000000. mean reward 213.998795.
# World Perf: Episode 2437.000000. Reward 200.000000. action: 0.000000. mean reward 43429.578125.
# World Perf: Episode 2440.000000. Reward 200.000000. action: 0.000000. mean reward 42570.160156.
# World Perf: Episode 2443.000000. Reward 200.000000. action: 0.000000. mean reward 41728.199219.
# World Perf: Episode 2446.000000. Reward 200.000000. action: 0.000000. mean reward 112485502719885312.000000.
# World Perf: Episode 2449.000000. Reward 187.666667. action: 0.000000. mean reward 110247034484686848.000000.
# World Perf: Episode 2452.000000. Reward 180.333333. action: 1.000000. mean reward 108053122240217088.000000.
# World Perf: Episode 2455.000000. Reward 185.000000. action: 0.000000. mean reward 105902864043343872.000000.
# World Perf: Episode 2458.000000. Reward 192.333333. action: 0.000000. mean reward 103795400900608000.000000.
# World Perf: Episode 2461.000000. Reward 198.666667. action: 0.000000. mean reward 101729873818550272.000000.
# World Perf: Episode 2464.000000. Reward 189.000000. action: 0.000000. mean reward 99705440983580672.000000.
# World Perf: Episode 2467.000000. Reward 187.333333. action: 1.000000. mean reward 97721303531782144.000000.
# World Perf: Episode 2470.000000. Reward 200.000000. action: 1.000000. mean reward 95776654009303040.000000.
# World Perf: Episode 2473.000000. Reward 200.000000. action: 0.000000. mean reward 93870702142160896.000000.
# World Perf: Episode 2476.000000. Reward 200.000000. action: 1.000000. mean reward 92002674836242432.000000.
# World Perf: Episode 2479.000000. Reward 200.000000. action: 0.000000. mean reward 90171824767238144.000000.
# World Perf: Episode 2482.000000. Reward 200.000000. action: 0.000000. mean reward 88377404610838528.000000.
# World Perf: Episode 2485.000000. Reward 199.333333. action: 0.000000. mean reward 86618692812537856.000000.
# World Perf: Episode 2488.000000. Reward 190.000000. action: 0.000000. mean reward 84894984997699584.000000.
# World Perf: Episode 2491.000000. Reward 200.000000. action: 1.000000. mean reward 83205576791687168.000000.
# World Perf: Episode 2494.000000. Reward 200.000000. action: 1.000000. mean reward 81549789589667840.000000.
# World Perf: Episode 2497.000000. Reward 200.000000. action: 0.000000. mean reward 79926944786808832.000000.
# World Perf: Episode 2500.000000. Reward 183.000000. action: 0.000000. mean reward 78336398138015744.000000.
# World Perf: Episode 2503.000000. Reward 188.000000. action: 0.000000. mean reward 76777513988128768.000000.
# World Perf: Episode 2506.000000. Reward 200.000000. action: 0.000000. mean reward 75249639502118912.000000.
# World Perf: Episode 2509.000000. Reward 200.000000. action: 0.000000. mean reward 73752173384564736.000000.
# World Perf: Episode 2512.000000. Reward 200.000000. action: 1.000000. mean reward 72284514340044800.000000.
# World Perf: Episode 2515.000000. Reward 200.000000. action: 0.000000. mean reward 70846052483203072.000000.
# World Perf: Episode 2518.000000. Reward 200.000000. action: 0.000000. mean reward 69436220878356480.000000.
# World Perf: Episode 2521.000000. Reward 200.000000. action: 0.000000. mean reward 68054443999887360.000000.
# World Perf: Episode 2524.000000. Reward 200.000000. action: 1.000000. mean reward 66700159207079936.000000.
# World Perf: Episode 2527.000000. Reward 200.000000. action: 1.000000. mean reward 65372825334054912.000000.
# World Perf: Episode 2530.000000. Reward 200.000000. action: 1.000000. mean reward 64071909804867584.000000.
# World Perf: Episode 2533.000000. Reward 200.000000. action: 0.000000. mean reward 62796884338540544.000000.
# World Perf: Episode 2536.000000. Reward 200.000000. action: 1.000000. mean reward 61547224949063680.000000.
# World Perf: Episode 2539.000000. Reward 200.000000. action: 0.000000. mean reward 60322437715197952.000000.
# World Perf: Episode 2542.000000. Reward 200.000000. action: 0.000000. mean reward 59122024420737024.000000.
# World Perf: Episode 2545.000000. Reward 200.000000. action: 1.000000. mean reward 57945495439409152.000000.
# World Perf: Episode 2548.000000. Reward 200.000000. action: 1.000000. mean reward 56792382619779072.000000.
# World Perf: Episode 2551.000000. Reward 200.000000. action: 1.000000. mean reward 55662213515444224.000000.
# 2551

# %% [markdown]
# ### Checking model representation
# Here we can examine how well the model is able to approximate the true environment after training. The green line indicates the real environment, and the blue indicates model predictions.

# %%
plt.figure(figsize=(8, 12))
for i in range(6):
    plt.subplot(6, 2, 2*i + 1)
    plt.plot(pState[:,i])
    plt.subplot(6,2,2*i+1)
    plt.plot(state_nextsAll[:,i])
plt.tight_layout()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ec5973aa3641> in <module>()
#       4     plt.plot(pState[:,i])
#       5     plt.subplot(6,2,2*i+1)
# ----> 6     plt.plot(state_nextsAll[:,i])
#       7 plt.tight_layout()
#
# NameError: name 'state_nextsAll' is not defined
